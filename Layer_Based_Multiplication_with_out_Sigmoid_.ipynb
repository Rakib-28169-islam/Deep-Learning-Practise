# %%
# weight matrix for 1st layer with 4(input)x3(hidden layer 1)
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
from IPython.display import Image
Image('/content/Image/Screenshot (514).png')

# %%
# random seed 42
torch.manual_seed(42)
W = torch.randn(4,3)
W
# Out:
# tensor([[ 0.3367,  0.1288,  0.2345],
#         [ 0.2303, -1.1229, -0.1863],
#         [ 2.2082, -0.6380,  0.4617],
#         [ 0.2674,  0.5349,  0.8094]])

# %%
# input matrix
torch.manual_seed(12)
X = torch.randn(4,1)
X
# Out:
# tensor([[-0.2138],
#         [-1.3780],
#         [-0.0546],
#         [ 0.4515]])

# %%
# hidden layer bias for 3 nodes
torch.manual_seed(15)
b = torch.randn(3,1)
b
# Out:
# tensor([[-0.7056],
#         [ 0.6741],
#         [-0.5454]])

# %%
O1 = W.T @ X + b
O1
# Out:
# tensor([[-1.0949e+00],
#         [ 2.4702e+00],
#         [ 1.5106e-03]])

# %%
# W = torch.randn(512, 256).to(device)      # weight matrix
# X = torch.randn(512, 1).to(device)       # input vector
# b = torch.randn(256).to(device)

# W.T @ X + b

# %%
Image('/content/Image/Screenshot (515).png')

# %%
W2 = torch.randn(3,2)
b2 = torch.randn(2,1)
W2,b2
# Out:
# (tensor([[ 0.9107,  1.0682],
#          [ 0.1424, -1.2754],
#          [-0.1769,  1.0084]]),
#  tensor([[-1.4611],
#          [-0.9257]]))

# %%
O2 = W2.T @ O1 + b2
O2
# Out:
# tensor([[-2.1068],
#         [-5.2442]])

# %%
Image('/content/Image/Screenshot (516).png')

# %%
W3 = torch.randn(2,1)
b3 = torch.randn(1,1)
W3,b3
# Out:
# (tensor([[2.5196],
#          [2.8843]]),
#  tensor([[0.0092]]))

# %%
O3 = W3.T @ O2 + b3
O3
# Out:
# tensor([[-20.4246]])
