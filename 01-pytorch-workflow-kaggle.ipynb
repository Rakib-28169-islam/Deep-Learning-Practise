# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
tensor = torch.tensor([1,2,3])
tensor.device
tensor_gpu = tensor.to(device)
tensor_gpu.device
# Out:
# device(type='cpu')

# %%
# tensor gpu to numpy
tensor_back_on_cpu = tensor_gpu.cpu().numpy()
tensor_back_on_cpu
# Out:
# array([1, 2, 3])

# %%
matA = torch.rand(7,7)
matB = torch.rand(1,7)
matA,matB
# Out:
# (tensor([[0.9408, 0.1332, 0.9346, 0.5936, 0.8694, 0.5677, 0.7411],
#          [0.4294, 0.8854, 0.5739, 0.2666, 0.6274, 0.2696, 0.4414],
#          [0.2969, 0.8317, 0.1053, 0.2695, 0.3588, 0.1994, 0.5472],
#          [0.0062, 0.9516, 0.0753, 0.8860, 0.5832, 0.3376, 0.8090],
#          [0.5779, 0.9040, 0.5547, 0.3423, 0.6343, 0.3644, 0.7104],
#          [0.9464, 0.7890, 0.2814, 0.7886, 0.5895, 0.7539, 0.1952],
#          [0.0050, 0.3068, 0.1165, 0.9103, 0.6440, 0.7071, 0.6581]]),
#  tensor([[0.4913, 0.8913, 0.1447, 0.5315, 0.1587, 0.6542, 0.3278]]))

# %%
matA@matB.T
# Out:
# tensor([[1.7840],
#         [1.6456],
#         [1.4124],
#         [1.9116],
#         [1.9238],
#         [2.2789],
#         [1.5571]])

# %%
# prompt: give me example of random seed to 0

import random
random.seed(0)
torch.manual_seed(0)
tensor = torch.rand(3,3)
torch.manual_seed(0)
tensor1 = torch.rand(3,3)
tensor == tensor1
# Out:
# tensor([[True, True, True],
#         [True, True, True],
#         [True, True, True]])

# %%
# import torch

# # Set manual seed for reproducibility
# torch.manual_seed(1234)

# # Create two random tensors of shape (2, 3)
# tensor_A = torch.rand((2, 3))
# torch.manual_seed(1234)
# tensor_B = torch.rand((2, 3))

# # Send both tensors to GPU
# tensor_A_gpu = tensor_A.to("cuda")
# tensor_B_gpu = tensor_B.to("cuda")

# # Print the results
# print("Tensor A (on GPU):\n", tensor_A_gpu)
# print("Tensor B (on GPU):\n", tensor_B_gpu)
# print("max number of  Tensor A:  ",tensor_A_gpu.max())
# print("min number of  Tensor A:  ",tensor_A_gpu.min())
# print("max number of  Tensor B:  ",tensor_B_gpu.max())
# print("min number of  Tensor B:  ",tensor_B_gpu.min())
# print("index of max number of Tensor A : ",tensor_A_gpu.argmax())
# print("index of min number of Tensor A : ",tensor_A_gpu.argmin())
# print("index of max number of Tensor B : ",tensor_B_gpu.argmax())
# print("index of min number of Tensor B : ",tensor_B_gpu.argmin())

# %%
import torch

# Set the seed
torch.manual_seed(7)

# Create a random tensor with shape (1, 1, 1, 10)
tensor = torch.rand(1, 1, 1, 10)

# Remove all dimensions of size 1
squeezed_tensor = tensor.squeeze()

# Print both tensors and their shapes
print("Original tensor:\n", tensor)
print("Original shape:", tensor.shape)

print("\nSqueezed tensor:\n", squeezed_tensor)
print("Squeezed shape:", squeezed_tensor.shape)
# Out:
# Original tensor:
#  tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]])
# Original shape: torch.Size([1, 1, 1, 10])
#
# Squeezed tensor:
#  tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513])
# Squeezed shape: torch.Size([10])

# %%
what_were_covering = {1: "data (prepare and load)",
    2: "build model",
    3: "fitting the model to data (training)",
    4: "making predictions and evaluating a model (inference)",
    5: "saving and loading a model",
    6: "putting it all together"
}
what_were_covering
# Out:
# {1: 'data (prepare and load)',
#  2: 'build model',
#  3: 'fitting the model to data (training)',
#  4: 'making predictions and evaluating a model (inference)',
#  5: 'saving and loading a model',
#  6: 'putting it all together'}

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

# Create device
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
weight = 0.7
bias = 0.3

st = 0
en = 1
step = 0.02
X = torch.arange(st,en,step).unsqueeze(dim=1)
y = weight * X + bias

# %%
X
# Out:
# tensor([[0.0000],
#         [0.0200],
#         [0.0400],
#         [0.0600],
#         [0.0800],
#         [0.1000],
#         [0.1200],
#         [0.1400],
#         [0.1600],
#         [0.1800],
#         [0.2000],
#         [0.2200],
#         [0.2400],
#         [0.2600],
#         [0.2800],
#         [0.3000],
#         [0.3200],
#         [0.3400],
#         [0.3600],
#         [0.3800],
#         [0.4000],
#         [0.4200],
#         [0.4400],
#         [0.4600],
#         [0.4800],
#         [0.5000],
#         [0.5200],
#         [0.5400],
#         [0.5600],
#         [0.5800],
#         [0.6000],
#         [0.6200],
#         [0.6400],
#         [0.6600],
#         [0.6800],
#         [0.7000],
#         [0.7200],
#         [0.7400],
#         [0.7600],
#         [0.7800],
#         [0.8000],
#         [0.8200],
#         [0.8400],
#         [0.8600],
#         [0.8800],
#         [0.9000],
#         [0.9200],
#         [0.9400],
#         [0.9600],
# ...

# %%
y
# Out:
# tensor([[0.3000],
#         [0.3140],
#         [0.3280],
#         [0.3420],
#         [0.3560],
#         [0.3700],
#         [0.3840],
#         [0.3980],
#         [0.4120],
#         [0.4260],
#         [0.4400],
#         [0.4540],
#         [0.4680],
#         [0.4820],
#         [0.4960],
#         [0.5100],
#         [0.5240],
#         [0.5380],
#         [0.5520],
#         [0.5660],
#         [0.5800],
#         [0.5940],
#         [0.6080],
#         [0.6220],
#         [0.6360],
#         [0.6500],
#         [0.6640],
#         [0.6780],
#         [0.6920],
#         [0.7060],
#         [0.7200],
#         [0.7340],
#         [0.7480],
#         [0.7620],
#         [0.7760],
#         [0.7900],
#         [0.8040],
#         [0.8180],
#         [0.8320],
#         [0.8460],
#         [0.8600],
#         [0.8740],
#         [0.8880],
#         [0.9020],
#         [0.9160],
#         [0.9300],
#         [0.9440],
#         [0.9580],
#         [0.9720],
# ...

# %%
X[:10],y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %%
train_split = int(0.8*len(X))
train_split
# Out:
# 40

# %%
X_train,y_train = X[:train_split],y[:train_split]
X_test,y_test = X[train_split:],y[train_split:]
len(X_train),len(y_train),len(X_test),len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
def plot_prediction(
    train_data = X_train,
    train_labels =y_train,
    test_data = X_test,
    test_labels = y_test,
    predictions = None):
  plt.figure(figsize=(10,7))
  plt.scatter(train_data,train_labels, c="b",s=4,label="training data")
  plt.scatter(test_data,test_labels,c="g",s=4,label="testing data")
  if predictions is not None:
    plt.scatter(test_data,predictions,c="r",s=4,label="prediction data")
  plt.legend(prop={"size":20})

# %%
plot_prediction()

# %%
# Create a Linear Regression model class
class LinearRegressionModel(nn.Module): # <- almost everything in PyTorch is a nn.Module (think of this as neural network lego blocks)
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(1, # <- start with random weights (this will get adjusted as the model learns)
                                                dtype=torch.float), # <- PyTorch loves float32 by default
                                   requires_grad=True) # <- can we update this value with gradient descent?)

        self.bias = nn.Parameter(torch.randn(1, # <- start with random bias (this will get adjusted as the model learns)
                                            dtype=torch.float), # <- PyTorch loves float32 by default
                                requires_grad=True) # <- can we update this value with gradient descent?))
        

    # Forward defines the computation in the model
    def forward(self, x: torch.Tensor) -> torch.Tensor: # <- "x" is the input data (e.g. training/testing features)
        return self.weights * x + self.bias # <- this is the linear regression formula (y = m*x + b)

# %%
# Set manual seed since nn.Parameter are randomly initialized
torch.manual_seed(42)

model_0 = LinearRegressionModel()

list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
with torch.inference_mode():
    y_preds = model_0(X_test)

# %%
print(f"Number of testing samples: {len(X_test)}") 
print(f"Number of predictions made: {len(y_preds)}")
print(f"Predicted values:\n{y_preds}")
# Out:
# Number of testing samples: 10
# Number of predictions made: 10
# Predicted values:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_prediction(predictions = y_preds)

# %%
#it times now create loss function and optimize our model params

loss_fn = nn.L1Loss()
optimizer = torch.optim.SGD(params = model_0.parameters(),lr=0.01)

# %%
#tune our params

epochs = 200
train_loss_values = []
test_loss_values  = []
epoch_count =[]

for epoch in range(epochs):
    model_0.train()

    y_pred = model_0(X_train)
    loss = loss_fn(y_pred,y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    model_0.eval()

    with torch.inference_mode():
        test_pred = model_0(X_test)
        test_loss = loss_fn(test_pred, y_test.type(torch.float))
        
        if epoch % 10 == 0:
            epoch_count.append(epoch)
            train_loss_values.append(loss.detach().numpy())
            test_loss_values.append(test_loss.detach().numpy())
            print(f"Epoch: {epoch} | MAE Train Loss: {loss} | MAE Test Loss: {test_loss} ")
# Out:
# Epoch: 0 | MAE Train Loss: 0.024458957836031914 | MAE Test Loss: 0.05646304413676262
# Epoch: 10 | MAE Train Loss: 0.021020207554101944 | MAE Test Loss: 0.04819049686193466
# Epoch: 20 | MAE Train Loss: 0.01758546568453312 | MAE Test Loss: 0.04060482233762741
# Epoch: 30 | MAE Train Loss: 0.014155393466353416 | MAE Test Loss: 0.03233227878808975
# Epoch: 40 | MAE Train Loss: 0.010716589167714119 | MAE Test Loss: 0.024059748277068138
# Epoch: 50 | MAE Train Loss: 0.0072835334576666355 | MAE Test Loss: 0.016474086791276932
# Epoch: 60 | MAE Train Loss: 0.0038517764769494534 | MAE Test Loss: 0.008201557211577892
# Epoch: 70 | MAE Train Loss: 0.008932482451200485 | MAE Test Loss: 0.005023092031478882
# Epoch: 80 | MAE Train Loss: 0.008932482451200485 | MAE Test Loss: 0.005023092031478882
# Epoch: 90 | MAE Train Loss: 0.008932482451200485 | MAE Test Loss: 0.005023092031478882
# Epoch: 100 | MAE Train Loss: 0.008932482451200485 | MAE Test Loss: 0.005023092031478882
# ...

# %%
# 1. Set the model in evaluation mode
model_0.eval()

# 2. Setup the inference mode context manager
with torch.inference_mode():
  # 3. Make sure the calculations are done with the model and data on the same device
  # in our case, we haven't setup device-agnostic code yet so our data and model are
  # on the CPU by default.
  # model_0.to(device)
  # X_test = X_test.to(device)
  y_preds = model_0(X_test)

# %%
plot_prediction(predictions = y_preds)

# %%
from pathlib import Path

# 1. Create models directory 
MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# 2. Create model save path 
MODEL_NAME = "01_pytorch_workflow_model_0.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict 
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_0.state_dict(), # only saving the state_dict() only saves the models learned parameters
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/01_pytorch_workflow_model_0.pth

# %%
# Check the saved file path
# !ls -l models/01_pytorch_workflow_model_0.pth
# Out:
# -rw-r--r-- 1 root root 1680 May 27 17:25 models/01_pytorch_workflow_model_0.pth

# %%
# Instantiate a new instance of our model (this will be instantiated with random weights)
loaded_model_0 = LinearRegressionModel()

# Load the state_dict of our saved model (this will update the new instance of our model with trained weights)
loaded_model_0.load_state_dict(torch.load(f=MODEL_SAVE_PATH))
# Out:
# <All keys matched successfully>

# %%
model = LinearRegressionModel()
model.load_state_dict(torch.load("/kaggle/input/l1_new/pytorch/default/1/01_pytorch_workflow_model_0 (1).pth"))

# 1. Put the loaded model into evaluation mode
model.eval()

# 2. Use the inference mode context manager to make predictions
with torch.inference_mode():
    model_preds = model(X_test) # perform a forward pass on the test data with the loaded model
# Compare previous model predictions with loaded model predictions (these should be the same)
y_preds == model_preds
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
